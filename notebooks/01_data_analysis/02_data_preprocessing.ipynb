# %% [markdown]
# # ⚙️ 02. Data Preprocessing & Merging
#
# **Objective:** Merge cleaned tables, handle date-time transformations, categorical encoding, and feature scaling.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
print("Imports completed.")

# %% [markdown]
# ## 2. Load Interim Datasets

# %%
interim_dir = "../../data/interim"
customers = pd.read_csv(os.path.join(interim_dir, "cleaned_customers.csv"))
orders = pd.read_csv(os.path.join(interim_dir, "cleaned_orders.csv"))
products = pd.read_csv(os.path.join(interim_dir, "cleaned_products.csv"))

# %% [markdown]
# ## 3. Merge Datasets
# Create a master e-commerce transactions table.

# %%
# Example of merge logic
# merged_df = orders.merge(customers, on='customer_id').merge(products, on='product_id')
# print(merged_df.head())

# %% [markdown]
# ## 4. Date-Time Parsing & Feature Extraction

# %%
# Parse dates and extract temporal features (e.g. Month, Day of week, Hour)
# orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
# orders['order_month'] = orders['order_purchase_timestamp'].dt.month
# orders['order_day_of_week'] = orders['order_purchase_timestamp'].dt.day_name()

# %% [markdown]
# ## 5. Scaling and Encoding

# %%
# Standardizing continuous variables & one-hot encoding categories
# scaler = StandardScaler()
# encoder = OneHotEncoder(sparse_output=False)

# %% [markdown]
# ## 6. Save Preprocessed Dataset

# %%
# merged_df.to_csv(os.path.join(interim_dir, 'preprocessed_ecommerce.csv'), index=False)
