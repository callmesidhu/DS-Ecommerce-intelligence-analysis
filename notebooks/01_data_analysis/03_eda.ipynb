# %% [markdown]
# # 📊 03. Exploratory Data Analysis (EDA)
#
# **Objective:** Analyze distributions, trends, seasonality, and correlations using visualizations.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
plt.style.use('seaborn-v0_8-whitegrid')

# %% [markdown]
# ## 2. Load Combined Data

# %%
# Load consolidated preprocessed e-commerce dataset

# %% [markdown]
# ## 3. Univariate Analysis
# Analyze distributions of single variables like sales, ratings, order count, and pricing.

# %%
# Plot distribution histograms & boxplots
# fig, ax = plt.subplots(1, 2, figsize=(12, 5))
# sns.histplot(data=df, x='price', kde=True, ax=ax[0])
# sns.boxplot(data=df, y='price', ax=ax[1])
# plt.show()

# %% [markdown]
# ## 4. Temporal Trends & Seasonality
# Visualize sales and order volume trends over months, days, and hours.

# %%
# Time series lineplot of monthly sales
# monthly_sales = df.groupby('month_year')['price'].sum()
# monthly_sales.plot(kind='line', figsize=(10, 5))
# plt.title('Monthly Sales Trend')

# %% [markdown]
# ## 5. Bivariate & Multivariate Analysis
# Explore relationships between variables, e.g., product categories, customer state, shipping delay vs review ratings.

# %%
# Heatmap correlation of numerical columns
# sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
