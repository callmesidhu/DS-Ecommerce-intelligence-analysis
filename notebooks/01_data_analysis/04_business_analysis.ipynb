# %% [markdown]
# # 💼 04. Business Metrics & KPI Analysis
#
# **Objective:** Calculate and analyze key business metrics: AOV, MRR, purchase frequency, cohort retention, and return rates.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# ## 2. Load E-commerce Data

# %%
# Load transaction datasets

# %% [markdown]
# ## 3. Average Order Value (AOV)
# Calculate how much customers typically spend on a single order.

# %%
# AOV = Total Revenue / Total Orders
# aov = df['price'].sum() / df['order_id'].nunique()
# print(f"Average Order Value: ${aov:.2f}")

# %% [markdown]
# ## 4. Cohort Retention Analysis
# Track customer cohorts based on their purchase month to analyze monthly retention rates.

# %%
# Group customers by signup/first order cohort and analyze repurchase behavior
# cohort_matrix = ...

# %% [markdown]
# ## 5. Return Rate & Refund KPI
# Understand which categories and products experience high return rates.

# %%
# returns_rate = returned_orders / total_orders
# return_by_cat = df.groupby('category')['is_returned'].mean().sort_values(ascending=False)
