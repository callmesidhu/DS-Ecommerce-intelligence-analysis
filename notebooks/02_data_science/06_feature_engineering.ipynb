# %% [markdown]
# # 🔨 06. Feature Engineering & Advanced Predictors
#
# **Objective:** Build customer-level aggregate features, temporal features, rolling statistics, and text-based metrics.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import os
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## 2. Load Consolidated Datasets

# %%
# Load transactional records

# %% [markdown]
# ## 3. Customer-Level Aggregations
# Build cumulative indicators of customer purchase behavior: average order value, total transaction count, preference category.

# %%
# customer_features = df.groupby('customer_id').agg({
#     'price': ['sum', 'mean'],
#     'order_id': 'nunique',
#     'rating': 'mean'
# })

# %% [markdown]
# ## 4. Time-Series / Lag Features
# For forecasting, create lagged predictors (e.g., sales from t-1, t-7, t-30) and rolling averages.

# %%
# df['sales_lag_7'] = df['daily_sales'].shift(7)
# df['sales_roll_mean_30'] = df['daily_sales'].rolling(window=30).mean()

# %% [markdown]
# ## 5. Export Feature Matrix
# Save finalized features into the `data/processed` folder.

# %%
# os.makedirs('../../data/processed', exist_ok=True)
# feature_matrix.to_csv('../../data/processed/engineered_features.csv', index=True)
