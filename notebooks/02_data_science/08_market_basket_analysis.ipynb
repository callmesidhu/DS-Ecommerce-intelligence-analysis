# %% [markdown]
# # 🛒 08. Market Basket Analysis & Association Rules
#
# **Objective:** Identify association rules between purchase items using Apriori and FP-Growth algorithms.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
# Note: Requires mlxtend library (install via pip if missing)
# from mlxtend.frequent_patterns import apriori, association_rules
print("Association rule mining libraries prepared.")

# %% [markdown]
# ## 2. Prepare Order Transactions (One-Hot Format)

# %%
# Create cross tab or one-hot matrix of orders vs products
# basket = (order_items.groupby(['order_id', 'product_id'])['quantity']
#           .sum().unstack().reset_index().fillna(0)
#           .set_index('order_id'))
# basket = basket.map(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# ## 3. Run Association Rule Algorithms

# %%
# frequent_itemsets = apriori(basket, min_support=0.01, use_colnames=True)
# rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0)

# %% [markdown]
# ## 4. Analyze Results & Recommending Product Bundles

# %%
# Filter rules by high confidence and lift
# print(rules.sort_values(by='lift', ascending=False).head(10))
