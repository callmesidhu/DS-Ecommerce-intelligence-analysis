# %% [markdown]
# # 📐 09. Statistical Data Analysis
#
# **Objective:** Perform statistical analysis, study variables distribution, check normality, and compute confidence intervals.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## 2. Load Sales Data

# %%
# Load cleaned metrics

# %% [markdown]
# ## 3. Probability Distributions & Normality Testing
# Check whether purchase amount or order count follows a normal or log-normal distribution.

# %%
# Shapiro-Wilk and QQ plots
# stats.probplot(df['price'], dist="norm", plot=plt)
# plt.show()
# print(stats.shapiro(df['price'].sample(5000)))

# %% [markdown]
# ## 4. Confidence Intervals
# Calculate the 95% Confidence Interval for mean order value.

# %%
# mean = df['price'].mean()
# sem = stats.sem(df['price'])
# ci = stats.t.interval(0.95, df=len(df)-1, loc=mean, scale=sem)
# print(f"95% CI for average order value: {ci}")
