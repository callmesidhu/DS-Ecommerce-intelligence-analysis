# %% [markdown]
# # 🧪 10. Hypothesis Testing & A/B Experimentation
#
# **Objective:** Conduct T-Tests, ANOVA, and Chi-Square tests to validate business experiments.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import statsmodels.stats.api as sms

# %% [markdown]
# ## 2. A/B Testing Example: Conversion Rate comparison
# Compare conversions of Group A (Control) vs Group B (Treatment).

# %%
# Two-sample Z-test for proportions
# count = np.array([45, 60])
# nobs = np.array([1000, 1050])
# z_stat, p_val = sms.proportions_ztest(count, nobs)
# print(f"P-value of A/B test: {p_val:.4f}")

# %% [markdown]
# ## 3. T-Test: Comparing average purchase order values

# %%
# Independent two-sample t-test
# res = stats.ttest_ind(group_a_sales, group_b_sales, equal_var=False)

# %% [markdown]
# ## 4. ANOVA and Chi-Square Tests

# %%
# f_val, p_val = stats.f_oneway(group1, group2, group3)
# chi2, p, dof, ex = stats.chi2_contingency(contingency_table)
