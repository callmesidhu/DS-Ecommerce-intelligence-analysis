# %% [markdown]
# # 🎯 15. Product Recommendation System
#
# **Objective:** Implement collaborative (user-user, item-item, matrix factorization) and content-based recommendation systems.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from scipy.sparse import csr_matrix
from sklearn.metrics.pairwise import cosine_similarity
# from surprise import SVD, Dataset, Reader # optional
print("Recommendation libraries loaded.")

# %% [markdown]
# ## 2. Create User-Item Interaction Matrix

# %%
# pivot table of user vs item rating/purchases
# user_item_matrix = df.pivot(index='user_id', columns='item_id', values='rating').fillna(0)

# %% [markdown]
# ## 3. User-Based Collaborative Filtering

# %%
# user_sim = cosine_similarity(user_item_matrix)
# user_sim_df = pd.DataFrame(user_sim, index=user_item_matrix.index, columns=user_item_matrix.index)

# %% [markdown]
# ## 4. Item-Based Collaborative Filtering

# %%
# item_sim = cosine_similarity(user_item_matrix.T)

# %% [markdown]
# ## 5. Matrix Factorization (SVD)

# %%
# Perform singular value decomposition on interaction matrix
# u, sigma, vt = np.linalg.svd(user_item_matrix)
