# %% [markdown]
# # 🔧 17. Hyperparameter Optimization & Tuning
#
# **Objective:** Conduct systematic parameter optimization using Grid Search, Random Search, and Optuna.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import xgboost as xgb
# import optuna
print("Tuning libraries prepared.")

# %% [markdown]
# ## 2. Grid Search and Random Search Examples

# %%
# param_grid = { 'n_estimators': [100, 200], 'max_depth': [3, 5, 7] }
# grid = GridSearchCV(estimator=xgb.XGBClassifier(), param_grid=param_grid, cv=3)
# grid.fit(X_train, y_train)

# %% [markdown]
# ## 3. Advanced Optimization with Optuna

# %%
# def objective(trial):
#     param = {
#         'n_estimators': trial.suggest_int('n_estimators', 50, 300),
#         'max_depth': trial.suggest_int('max_depth', 3, 10)
#     }
#     clf = xgb.XGBClassifier(**param)
#     return cross_val_score(clf, X, y, cv=3).mean()
# study = optuna.create_study(direction='maximize')
# study.optimize(objective, n_trials=20)
