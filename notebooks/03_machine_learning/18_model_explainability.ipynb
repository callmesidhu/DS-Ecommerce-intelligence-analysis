# %% [markdown]
# # 👁️ 18. Model Explainability & Interpretability
#
# **Objective:** Explain machine learning model decisions using Feature Importance, SHAP values, and LIME.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
# import shap
# import lime
print("Explainability libraries prepared.")

# %% [markdown]
# ## 2. Traditional Feature Importance

# %%
# model = xgb.XGBClassifier().fit(X_train, y_train)
# feat_importances = pd.Series(model.feature_importances_, index=X.columns)
# feat_importances.nlargest(10).plot(kind='barh')

# %% [markdown]
# ## 3. Explaining with SHAP Values

# %%
# explainer = shap.TreeExplainer(model)
# shap_values = explainer.shap_values(X_test)
# shap.summary_plot(shap_values, X_test)

# %% [markdown]
# ## 4. Local Interpretability with LIME

# %%
# explainer_lime = lime.lime_tabular.LimeTabularExplainer(X_train.values, feature_names=X.columns)
# exp = explainer_lime.explain_instance(X_test.iloc[0], model.predict_proba)
