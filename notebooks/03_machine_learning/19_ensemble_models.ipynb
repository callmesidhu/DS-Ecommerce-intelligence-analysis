# %% [markdown]
# # 🔗 19. Ensemble Modeling Techniques
#
# **Objective:** Build Stacking, Voting, and Boosting ensembles to leverage aggregate learner capabilities.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import xgboost as xgb

# %% [markdown]
# ## 2. Define Base Estimators

# %%
# clf1 = RandomForestClassifier()
# clf2 = xgb.XGBClassifier()
# clf3 = LogisticRegression()

# %% [markdown]
# ## 3. Build Voting Classifier

# %%
# eclf = VotingClassifier(estimators=[('rf', clf1), ('xgb', clf2), ('lr', clf3)], voting='soft')
# eclf.fit(X_train, y_train)

# %% [markdown]
# ## 4. Build Stacking Classifier

# %%
# sclf = StackingClassifier(estimators=[('rf', clf1), ('xgb', clf2)], final_estimator=LogisticRegression())
# sclf.fit(X_train, y_train)
