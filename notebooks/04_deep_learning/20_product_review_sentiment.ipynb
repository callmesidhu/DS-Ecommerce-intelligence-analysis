# %% [markdown]
# # 💬 20. Product Review Sentiment Analysis with DL
#
# **Objective:** Process text comments and classify rating sentiment using feed-forward neural networks.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GlobalAveragePooling1D, Dense

# %% [markdown]
# ## 2. Text Preprocessing & Tokenization

# %%
# vocab_size = 10000
# max_length = 100
# tokenizer = Tokenizer(num_words=vocab_size, oov_token="<OOV>")
# tokenizer.fit_on_texts(train_sentences)
# sequences = tokenizer.texts_to_sequences(train_sentences)
# padded = pad_sequences(sequences, maxlen=max_length)

# %% [markdown]
# ## 3. Design and Train Deep Neural Network

# %%
# model = Sequential([
#     Embedding(vocab_size, 16, input_length=max_length),
#     GlobalAveragePooling1D(),
#     Dense(24, activation='relu'),
#     Dense(1, activation='sigmoid')
# ])
# model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# model.fit(padded, train_labels, epochs=10)
