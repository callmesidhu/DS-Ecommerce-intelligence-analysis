# %% [markdown]
# # 🌌 23. Deep Learning Recommendation Systems
#
# **Objective:** Implement Neural Collaborative Filtering (NCF) utilizing user and item embedding networks.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Flatten, Concatenate, Dense, Dropout

# %% [markdown]
# ## 2. Build NCF Network Model

# %%
# num_users = len(user_map)
# num_items = len(item_map)
# user_input = Input(shape=(1,), name='user')
# item_input = Input(shape=(1,), name='item')
# user_emb = Embedding(num_users, 16)(user_input)
# item_emb = Embedding(num_items, 16)(item_input)
# user_flat = Flatten()(user_emb)
# item_flat = Flatten()(item_emb)
# concat = Concatenate()([user_flat, item_flat])
# dense1 = Dense(64, activation='relu')(concat)
# output = Dense(1, activation='sigmoid')(dense1)
# model = Model(inputs=[user_input, item_input], outputs=output)

# %% [markdown]
# ## 3. Train Model

# %%
# model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
# model.fit([train_users, train_items], train_labels, epochs=5, batch_size=256)
