# %% [markdown]
# # 🤖 24. Transformer-based Sentiment & Text Analysis
#
# **Objective:** Leverage pretrained transformer architectures (Hugging Face) for review analysis.
#
# ---

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
# from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
print("Transformers environment ready.")

# %% [markdown]
# ## 2. Using Pretrained Pipelines (Sentiment Inference)

# %%
# classifier = pipeline("sentiment-analysis")
# results = classifier("This product is amazing, exceeded expectations!")
# print(results)

# %% [markdown]
# ## 3. Zero-shot Classification for Topic Profiling

# %%
# zero_shot = pipeline("zero-shot-classification")
# labels = ["quality", "shipping", "price", "customer service"]
# res = zero_shot("The delivery took forever and the package was damaged.", candidate_labels=labels)
# print(res)
